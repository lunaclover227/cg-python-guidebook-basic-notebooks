# %% [markdown]
# # 第4章　関数について詳しくなろう
#
# 第4章では、以下の項目について学びます。
#
# * 関数

# %% [markdown]
# ## 4.1　関数

# %% [markdown]
# ### 4.1.1　関数のおさらい

# %% [markdown]
# リスト4.1のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# Hello, world!
# ```

# %%
# ここにリスト4.1のコードを書き写す

# %% [markdown]
# ### 4.1.2　引数と戻り値

# %% [markdown]
# リスト4.2のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 3
# <class 'int'>
# ```

# %%
# ここにリスト4.2のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト4.3のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# Hello, world!
# None
# <class 'NoneType'>
# ```

# %%
# ここにリスト4.3のコードを書き写す

# %% [markdown]
# ### 4.1.5　引数のない関数、引数が複数ある関数

# %% [markdown]
# リスト4.4のコードを書き写してみましょう。
#
# 実行後、入力した数字に1足した数が表示されれば成功です。
#
# 【注意】数字以外を入力するとエラーになります

# %%
# ここにリスト4.4のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト4.5のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# True
# False
# False
# True
# False
# True
# ```

# %%
# ここにリスト4.5のコードを書き写す

# %% [markdown]
# ### 4.1.6　位置引数とキーワード引数

# %% [markdown]
# リスト4.6のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 大石泉 久川颯 夢見りあむ
# ```

# %%
# ここにリスト4.6のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト4.7のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 1.0
# <class 'float'>
# 1.0 <class 'float'>
# ```

# %%
# ここにリスト4.7のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト4.8のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 1.0
# <class 'float'>
# 1.0
# <class 'float'>
# ```

# %%
# ここにリスト4.8のコードを書き写す

# %% [markdown]
# ## 4.2　さまざまな関数とメソッド

# %% [markdown]
# ### 4.2.2　モジュールとimport

# %% [markdown]
# リスト4.10のコードを書き写してみましょう。
#
# 実行しても何も表示されません。

# %%
# ここにリスト4.10のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト4.11のコードを書き写してみましょう。
#
# 1から6までのいずれかの整数がランダムに表示されます。

# %%
# ここにリスト4.11のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト4.12のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# (※ここに何かしらの文字が入ります).py in <cell line: 0>()
#       1 # ここにリスト4.8のコードを書き写す
# ----> 2 randint(1, 6)
#
# NameError: name 'randint' is not defined
# ```

# %%
# ここにリスト4.12のコードを書き写す

# %% [markdown]
# ### 4.2.3　メソッド

# %% [markdown]
# リスト4.14のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# True
# ```

# %%
# ここにリスト4.14のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト4.15のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# True
# ```

# %%
# ここにリスト4.15のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト4.16のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 2
# ```

# %%
# ここにリスト4.16のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト4.17のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 6
# ```

# %%
# ここにリスト4.17のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト4.18のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 'チョコレート！レモネード！どっち！！'
# ```

# %%
# ここにリスト4.18のコードを書き写す

# %% [markdown]
# ### 4.2.4　オブジェクトと属性

# %% [markdown]
# リスト4.19のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'module'>
# <class 'method'>
# ```

# %%
# ここにリスト4.19のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト4.20のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
# (中略)
#  'zfill']
# ```

# %%
# ここにリスト4.20のコードを書き写す
