# %% [markdown]
# # 第4章　関数について詳しくなろう
#
# 第4章では、以下の項目について学びます。
#
# * 関数

# %% [markdown]
# ## 4.1　関数

# %% [markdown]
# ### 4.1.1　関数のおさらい

# %% [markdown]
# リスト4.1

# %%
print("Hello, world!")

# %% [markdown]
# ### 4.1.2　引数と戻り値

# %% [markdown]
# リスト4.2

# %%
int_result = int(3.14)
print(int_result)
print(type(int_result))

# %% [markdown]
# ---

# %% [markdown]
# リスト4.3

# %%
print_result = print("Hello, world!")
print(print_result)
print(type(print_result))

# %% [markdown]
# ### 4.1.5　引数のない関数、引数が複数ある関数

# %% [markdown]
# リスト4.4

# %%
inputted_number = input()
print(int(inputted_number) + 1)

# %% [markdown]
# ---

# %% [markdown]
# リスト4.5

# %%
print(isinstance(1, int))
print(isinstance(1.0, int))
print(isinstance(1, float))
print(isinstance(1.0, float))
print(isinstance('1', int))
print(isinstance('1', str))

# %% [markdown]
# ### 4.1.6　位置引数とキーワード引数

# %% [markdown]
# リスト4.6

# %%
print("大石泉", "久川颯", "夢見りあむ")

# %% [markdown]
# ---

# %% [markdown]
# リスト4.7

# %%
print(0.5 * 2)
print(type(0.5 * 2))

print(0.5 * 2, type(0.5 * 2))

# %% [markdown]
# ---

# %% [markdown]
# リスト4.8

# %%
print(0.5 * 2)
print(type(0.5 * 2))

print(0.5 * 2, type(0.5 * 2), sep="\n")

# %% [markdown]
# ## 4.2　さまざまな関数とメソッド

# %% [markdown]
# ### 4.2.2　モジュールとimport

# %% [markdown]
# リスト4.10

# %%
import random

# %% [markdown]
# ---

# %% [markdown]
# リスト4.11

# %%
random.randint(1, 6)

# %% [markdown]
# ---

# %% [markdown]
# リスト4.12

# %%
randint(1, 6)

# %% [markdown]
# ---

# %% [markdown]
# リスト4.13

# %%
import random
random.randint(1, 6)

# %% [markdown]
# ### 4.2.3　メソッド

# %% [markdown]
# リスト4.14

# %%
"久川颯".startswith("久川")

# %% [markdown]
# ---

# %% [markdown]
# リスト4.15

# %%
name = "久川颯"
name.startswith("久川")

# %% [markdown]
# ---

# %% [markdown]
# リスト4.16

# %%
"あかぎみりあとゆめみりあむ".count("みりあ")

# %% [markdown]
# ---

# %% [markdown]
# リスト4.17

# %%
"大石泉と学ぶPythonプログラミング".find("Python")

# %% [markdown]
# ---

# %% [markdown]
# リスト4.18

# %%
"チョコレート？レモネード？どっち？？".replace("？", "！")

# %% [markdown]
# ### 4.2.4　オブジェクトと属性

# %% [markdown]
# リスト4.19

# %%
print(type(print))
print(type("大石泉".startswith))
print(type(random))
print(type(random.randint))

# %% [markdown]
# ---

# %% [markdown]
# リスト4.20

# %%
dir("大石泉")
