# %% [markdown]
# # 第3章　いろいろな値を扱ってみよう
#
# 第3章では、以下の項目について学びます。
#
# *   四則演算
# *   変数

# %% [markdown]
# ## 3.1　四則演算

# %% [markdown]
# ### 3.1.1　足し算

# %% [markdown]
# リスト3.1のコードを書き写してみましょう。

# %%
# ここにリスト3.1のコードを書き写す
1 + 1
# Out:
# 2

# %% [markdown]
# 想定される出力結果は次の通りです。
#
#
#
# ```
# 2
# ```

# %% [markdown]
# ### 3.1.2　引き算

# %% [markdown]
# リスト3.2のコードを書き写してみましょう。
#
# 実行すると以下のように出力されます。
#
# ```
# 3
# ```

# %%
# ここにリスト3.2のコードを書き写す
5 - 2
# Out:
# 3

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
\
