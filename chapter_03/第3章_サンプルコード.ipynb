# %% [markdown]
# # 第3章　プログラムの基礎に触れてみよう
#
# 第3章では、以下の項目について学びます。
#
# *   四則演算
# *   変数

# %% [markdown]
# ## 3.1　四則演算

# %% [markdown]
# ### 3.1.1　足し算

# %% [markdown]
# リスト3.1

# %%
1 + 1

# %% [markdown]
# ### 3.1.2 引き算

# %% [markdown]
# リスト3.2
