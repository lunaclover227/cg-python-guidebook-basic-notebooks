# %% [markdown]
# # 第5章　複数の値をまとめてみよう
#
# 第5章では、以下の項目について学びます。
#
# * コレクション
# * シーケンス（リスト、文字列）
# * マッピング（辞書）

# %% [markdown]
# ## 5.1　コレクション

# %% [markdown]
# リスト5.1

# %%
(157 + 151 + 149) / 3

# %% [markdown]
# ---

# %% [markdown]
# リスト5.2

# %%
izumi_height = 157
hayate_height = 151
riamu_height = 149
print((izumi_height + hayate_height + riamu_height) / 3)

# %% [markdown]
# ## 5.2　シーケンス

# %% [markdown]
# ### 5.2.1　リスト

# %% [markdown]
# リスト5.4

# %%
height_list = [157, 151, 149]

# %% [markdown]
# ---

# %% [markdown]
# リスト5.5

# %%
height_list = [157, 151, 149]
print(height_list[0])

# %% [markdown]
# ---

# %% [markdown]
# リスト5.6

# %%
height_list = [157, 151, 149]
print((height_list[0] + height_list[1] + height_list[2]) / 3)

# %% [markdown]
# ---

# %% [markdown]
# リスト5.7

# %%
height_list = [157, 151, 149]
print(sum(height_list) / 3)

# %% [markdown]
# ---

# %% [markdown]
# リスト5.8

# %%
height_list = [157, 151, 149]
print(sum(height_list) / len(height_list))

# %% [markdown]
# ### 5.2.2　文字列

# %% [markdown]
# リスト5.9

# %%
name = "大石泉"
print(name[2])

# %% [markdown]
# ### 5.2.3　シーケンスの代表的な演算

# %% [markdown]
# リスト5.10

# %%
name = "夢見りあむ"
print(name[2:4])
print(name[2:])
print(name[:4])
print(name[:])

# %% [markdown]
# ---

# %% [markdown]
# リスト5.11

# %%
"大石泉"[3]

# %% [markdown]
# ---

# %% [markdown]
# リスト5.12

# %%
name_list = ["大石泉", "久川颯", "夢見りあむ"]
print("大石泉" in name_list)
print("辻野あかり" in name_list)
print("夢見りあむ" not in name_list)
print("砂塚あきら" not in name_list)

# %% [markdown]
# ### 5.2.4　リストのメソッドと破壊的操作

# %% [markdown]
# リスト5.13

# %%
list_a = [1, 2]
list_b = [3, 4]
list_a.extend(list_b)
print(list_a)

# %% [markdown]
# ---

# %% [markdown]
# リスト5.14

# %%
song_title = "チョコレート？レモネード？どっち？？"
new_song_title = song_title.replace("？", "！")
print(song_title)
print(new_song_title)

# %% [markdown]
# ---

# %% [markdown]
# リスト5.15

# %%
list_a = [1, 2]
list_b = [3, 4]
list_c = list_a.extend(list_b)
print(list_a)
print(list_b)
print(list_c)

# %% [markdown]
# ---

# %% [markdown]
# リスト5.16

# %%
list_a = [1, 2]
list_b = [3, 4]
print(list_a.extend(list_b))
print(list_a)
print(list_a.extend(list_b))
print(list_a)
print(list_a.extend(list_b))
print(list_a)

# %% [markdown]
# ---

# %% [markdown]
# リスト5.17

# %%
list_d = [1, 2]
list_e = [3, 4]
list_d.append(list_e)
print(list_d)

# %% [markdown]
# ---

# %% [markdown]
# リスト5.18

# %%
print(len(list_d))
print(list_d[0])
print(list_d[1])
print(list_d[2])
print(list_d[2][0])
print(list_d[2][1])

# %% [markdown]
# ### 5.2.5　リストの使いどころ

# %% [markdown]
# リスト5.19

# %%
year = 2025
month = 11
day = 11

# %% [markdown]
# ---

# %% [markdown]
# リスト5.20

# %%
today_list = [2025, 11, 11]

# %% [markdown]
# ---

# %% [markdown]
# リスト5.21

# %%
import datetime
date_today = datetime.date(2025, 11, 11)
print(date_today.year)
print(date_today.month)
print(date_today.day)

# %% [markdown]
# ## 5.3　マッピング

# %% [markdown]
# ### 5.3.1　辞書

# %% [markdown]
# リスト5.22

# %%
height_dict = {"大石泉": 157, "久川颯": 151, "夢見りあむ": 149}
print(height_dict["大石泉"])
print(height_dict["久川颯"])
print(height_dict["夢見りあむ"])
print(height_dict)

# %% [markdown]
# ---

# %% [markdown]
# リスト5.23

# %%
height_to_idols = {
    151: ["久川颯", "浅利七海", "棟方愛海", "依田芳乃", "喜多日菜子"],
    150: ["久川凪", "ライラ", "成宮由愛", "矢口美羽", "望月聖"],
    149: ["森久保乃々", "夢見りあむ", "三好紗南", "中野有香", "城ヶ崎莉嘉"]
}
print(height_to_idols[151])

# %% [markdown]
# ### 5.3.2　マッピングの代表的な演算

# %% [markdown]
# リスト5.25

# %%
height_dict = {"大石泉": 157, "久川颯": 151, "夢見りあむ": 149}
height_dict["村松さくら"] = 145
height_dict["土屋亜子"] = 156

print(height_dict["村松さくら"])
print(height_dict["土屋亜子"])
print(height_dict)

# %% [markdown]
# ---

# %% [markdown]
# リスト5.27

# %%
height_dict = {"大石泉": 157, "久川颯": 151, "夢見りあむ": 149}
height_dict["村松さくら"] = 145
height_dict["土屋亜子"] = 156
del height_dict["久川颯"]
del height_dict["夢見りあむ"]

print(height_dict["村松さくら"])
print(height_dict["土屋亜子"])
print(height_dict)

# %% [markdown]
# ---

# %% [markdown]
# リスト5.28

# %%
height_dict = {"大石泉": 157, "久川颯": 151, "夢見りあむ": 149}
print("大石泉" in height_dict)
print("辻野あかり" in height_dict)
print("夢見りあむ" not in height_dict)
print("砂塚あきら" not in height_dict)

# %% [markdown]
# ---

# %% [markdown]
# リスト5.29

# %%
height_dict = {"大石泉": 157, "久川颯": 151, "夢見りあむ": 149}
print(height_dict["辻野あかり"])

# %% [markdown]
# ---

# %% [markdown]
# リスト5.30

# %%
height_dict = {"大石泉": 157, "久川颯": 151, "夢見りあむ": 149}
print(157 in height_dict.values())
print(150 in height_dict.values())
print(148 not in height_dict.values())
print(151 not in height_dict.values())

# %% [markdown]
# ---

# %% [markdown]
# リスト5.31

# %%
height_dict = {"大石泉": 157, "久川颯": 151, "夢見りあむ": 149}
print("大石泉" in height_dict.keys())
print("辻野あかり" in height_dict.keys())
print("夢見りあむ" not in height_dict.keys())
print("砂塚あきら" not in height_dict.keys())
