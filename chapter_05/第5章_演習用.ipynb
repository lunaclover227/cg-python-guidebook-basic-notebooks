# %% [markdown]
# # 第5章　複数の値をまとめてみよう
#
# 第5章では、以下の項目について学びます。
#
# * シーケンス
#   * リスト
#   * 文字列
#
# * マッピング
#   * 辞書

# %% [markdown]
# ## 5.1　コレクション

# %% [markdown]
# リスト5.1のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 152.33333333333334
# ```

# %%
# ここにリスト5.1のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト5.2のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 152.33333333333334
# ```

# %%
# ここにリスト5.2のコードを書き写す

# %% [markdown]
# ## 5.2　シーケンス

# %% [markdown]
# ### 5.2.1　リスト

# %% [markdown]
# リスト5.4のコードを書き写して実行してみましょう。
# この時点では何も表示されませんが、続いてリスト5.5のように、2行目に `print(height_list[0])` と書き加え再度実行してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 157
# ```

# %%
# ここにリスト5.4および5.5のコードを書き写す

# %% [markdown]
# その後、以下のコードを実行し、`sum()` や `len()` を利用して計算式を書き換えられることを確認しましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 152.33333333333334
# 152.33333333333334
# 152.33333333333334
# ```

# %%
# リスト5.6 (リストの要素を足して割るだけ)
print((height_list[0] + height_list[1] + height_list[2]) / 3)

# リスト5.7 (リストの合計をsum()で計算)
print(sum(height_list) / 3)

# リスト5.8 (リストの要素数で割り算)
print(sum(height_list) / len(height_list))

# %% [markdown]
# ### 5.2.2　文字列

# %% [markdown]
# リスト5.9のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 泉
# ```

# %%
# ここにリスト5.9のコードを書き写す

# %% [markdown]
# ### 5.2.3　シーケンスの代表的な演算

# %% [markdown]
# リスト5.10のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# りあ
# りあむ
# 夢見りあ
# 夢見りあむ
# ```

# %%
# ここにリスト5.10のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト5.11のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# (※ここに何かしらの文字が入ります).py in <cell line: 0>()
#       1 # ここにリスト4.7のコードを書き写す
# ----> 2 "大石泉"[3]
#
# IndexError: string index out of range
# ```

# %%
# ここにリスト4.7のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト5.12のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# True
# False
# False
# True
# ```

# %%
# ここにリスト5.12のコードを書き写す

# %% [markdown]
# ### 5.2.4　リストのメソッドと破壊的動作

# %% [markdown]
# リスト5.13のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# [1, 2, 3, 4]
# ```

# %%
# ここにリスト5.13のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト5.14のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# チョコレート？レモネード？どっち？？
# チョコレート！レモネード！どっち！！
# ```

# %%
# ここにリスト5.14のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト5.15のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# [1, 2, 3, 4]
# [3, 4]
# None
# ```

# %%
# ここにリスト5.15のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト5.16のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# None
# [1, 2, 3, 4]
# None
# [1, 2, 3, 4, 3, 4]
# None
# [1, 2, 3, 4, 3, 4, 3, 4]
# ```

# %%
# ここにリスト5.16のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト5.17のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# [1, 2, [3, 4]]
# ```

# %%
# ここにリスト5.17のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト5.18のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 3
# 1
# 2
# [3, 4]
# 3
# 4
# ```

# %%
# ここにリスト5.18のコードを書き写す

# %% [markdown]
# ### 5.2.5　リストの使いどころ

# %% [markdown]
# リスト5.19および5.20は実行しても何も表示されないため、目視での確認のみで問題ありません。
#
# 続いて、リスト5.21のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 2025
# 11
# 11
# ```

# %%
# ここにリスト5.21のコードを書き写す

# %% [markdown]
# ## 5.3　マッピング

# %% [markdown]
# ### 5.3.1　辞書

# %% [markdown]
# リスト5.22のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 157
# 151
# 149
# {'大石泉': 157, '久川颯': 151, '夢見りあむ': 149}
# ```

# %%
# ここにリスト5.22のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# 以下のコード(リスト5.23)を実行しましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# ['久川颯', '浅利七海', '棟方愛海', '依田芳乃', '喜多日菜子']
# ```

# %%
height_to_idols = {
    151: ["久川颯", "浅利七海", "棟方愛海", "依田芳乃", "喜多日菜子"],
    150: ["久川凪", "ライラ", "成宮由愛", "矢口美羽", "望月聖"],
    149: ["森久保乃々", "夢見りあむ", "三好紗南", "中野有香", "城ヶ崎莉嘉"]
}
print(height_to_idols[151])

# %% [markdown]
# ### 5.3.2　マッピングの代表的な演算

# %% [markdown]
# リスト5.25のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 145
# 156
# {'大石泉': 157, '久川颯': 151, '夢見りあむ': 149, '村松さくら': 145, '土屋亜子': 156}
# ```
#
# 続けて、リスト5.27のように、4行目と5行目にdel文を追加して再度実行しましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 145
# 156
# {'大石泉': 157, '村松さくら': 145, '土屋亜子': 156}
# ```

# %%
# ここにリスト5.25および5.27のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト5.28のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# True
# False
# False
# True
# ```

# %%
# ここにリスト5.28のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト5.29のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# (※ここに何かしらの文字が入ります).py in <cell line: 0>()
#       1 # ここにリスト5.29のコードを書き写す
#       2 height_dict = {"大石泉": 157, "久川颯": 151, "夢見りあむ": 149}
# ----> 3 print(height_dict["辻野あかり"])
#
# KeyError: '辻野あかり'
# ```

# %%
# ここにリスト5.29のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト5.30のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# True
# False
# True
# False
# ```

# %%
# ここにリスト5.30のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# 最後にリスト5.31のコードを実行し、`dict.keys()` でもkeyの存在を判定できることを確認しましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# True
# False
# False
# True
# ```

# %%
height_dict = {"大石泉": 157, "久川颯": 151, "夢見りあむ": 149}
print("大石泉" in height_dict.keys())
print("辻野あかり" in height_dict.keys())
print("夢見りあむ" not in height_dict.keys())
print("砂塚あきら" not in height_dict.keys())
