# %% [markdown]
# # 第6章　文を使いこなそう
#
# 第6章では、以下の項目について学びます。
#
# * if文
# * for文
# * while文

# %% [markdown]
# ## 6.2　if文

# %% [markdown]
# ### 6.2.3　ifとelse

# %% [markdown]
# リスト6.5のコードを書き写してみましょう。
#
# 実行後、以下のいずれかの文字列を入力し、「一致する属性があります！」と表示されれば成功です。
#
# * キュート
# * クール
# * パッション
#
# このとき、それ以外の文字列を入力しても何も表示されません。
#
# 続けて、リスト6.7のように、後ろにelse文を追加してみましょう。実行後、上記のいずれでもない文字列を入力し、「そのような属性はありません」と表示されれば成功です。

# %%
# ここにリスト6.5および6.7のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# 以下のコード(リスト6.8)を実行してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# それはそう
# ```

# %%
if "大石泉すき":
    print("それはそう")
else:
    print("そんなはずはない")

# %% [markdown]
# ---

# %% [markdown]
# 以下のコード(リスト6.9)を実行してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# True
# False
# ```

# %%
print(bool("大石泉すき"))
print(bool([]))

# %% [markdown]
# ### 6.2.4　比較演算

# %% [markdown]
# 以下のコード(リスト6.9)を実行してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# True False False
# True True False
# True False
# False True
# True
# False
# ```

# %%
print(3 > 2, 3 > 3, 2 > 3)
print(3 >= 2, 3 >= 3, 2 >= 3)
print(3 == 3, 3 == 2)
print(3 != 3, 3 != 2)
print(3 == 3.0)
print(3 == "3")
# Out:
# True False False
# True True False
# True False
# False True
# True
# False

# %% [markdown]
# ---

# %% [markdown]
# リスト6.11のコードを書き写してみましょう。
#
# 実行後、以下の文字列が表示されれば成功です。
#
# * 18以上の整数を入力したとき
#
# ```
# あなたは成人です
# ```
# * 18未満の整数を入力したとき
#
# ```
# あなたは未成年者です
# ```
#
# 【注意】小数でも動作はしますが、数値以外を入力するとエラーになります。

# %%
# ここにリスト6.11のコードを書き写す

# %% [markdown]
# ### 6.2.5　andとor

# %% [markdown]
# リスト6.11のコードを書き写してみましょう。
#
# 実行後、以下の文字列が表示されれば成功です。
#
# * 年齢を15、身長を157と入力したとき
#
# ```
# あなたの年齢と身長は大石泉と同じです
# ```
# * 上記の条件を満たさなかったとき
#
# ```
# あなたの年齢や身長の少なくとも一方は大石泉と異なります
# ```
#
# 【注意】小数でも動作はしますが、数値以外を入力するとエラーになります。

# %%
# ここにリスト6.11のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト6.13のコードを書き写してみましょう。
#
# 実行後、以下の文字列が表示されれば成功です。
#
# * 久川から始まる名前を入力し、かつ身長を150と入力したとき
# * 身長を151と入力したとき
#
# ```
# あなたは久川姉妹のどちらかである可能性があります
# ```
# * 上記の条件を満たさなかったとき
#
# ```
# あなたは凪でも颯でもありません
# ```
#
# 続けて、リスト6.14のように4行目の身長の判定を `()` で括り、身長を151と入力しただけでは「あなたは久川姉妹のどちらかである可能性があります」と表示されなくなることを確認しましょう。
#
# 【注意】小数でも動作はしますが、数値以外を入力するとエラーになります。

# %%
# ここにリスト6.13および6.14のコードを書き写す

# %% [markdown]
# 最後に以下のコード(リスト6.15および6.16)を実行し、リスト6.14と挙動が同じことを確認しましょう。

# %%
# リスト6.15
name = input("あなたの名前は？")
height = int(input("あなたの身長は何cm？"))

if name.startswith("久川"):
    if height == 150 or height == 151:
        print("あなたは久川姉妹のどちらかである可能性があります")
else:
    print("あなたは凪でも颯でもありません")

# %%
# リスト6.16
name = input("あなたの名前は？")
height = int(input("あなたの身長は何cm？"))

is_height_hisakawa = (height == 150 or height == 151)

if name.startswith("久川") or is_height_hisakawa:
    print("あなたは久川姉妹のどちらかである可能性があります")
else:
    print("あなたは凪でも颯でもありません")

# %% [markdown]
# ---

# %% [markdown]
# 以下のコード(リスト6.17および6.18)を実行し、以下の文字列が表示されれば成功です。条件の最後の `== True` の有無が影響しないことを確認しましょう。
#
# * 久川から始まる名前を入力したとき
#
# ```
# あなたは久川家の人ですか？
# ```
# * 上記の条件を満たさなかったとき
#
# ```
# (何も表示されない)
# ```

# %%
# リスト6.17
name = input("あなたの名前は？")
if name.startswith("久川") == True:
    print("あなたは久川家の人ですか？")

# %%
# リスト6.18
name = input("あなたの名前は？")
if name.startswith("久川"):
    print("あなたは久川家の人ですか？")

# %% [markdown]
# ---

# %% [markdown]
# 以下のコード(リスト6.19)を実行し、以下の文字列が表示されれば成功です。
#
# * 久川から始まる名前**以外**を入力したとき
#
# ```
# あなたは久川家の人ですか？
# ```
# * 上記の条件を満たさなかったとき
#
# ```
# (何も表示されない)
# ```

# %%
name = input("あなたの名前は？")
if not name.startswith("久川"):
    print("あなたは久川家の人ではありませんね？")

# %% [markdown]
# ### 6.2.6　elif

# %% [markdown]
# リスト6.21のコードを書き写してみましょう。
#
# 実行後、以下の文字列が表示されれば成功です。
#
# * 149以下の整数を入力したとき
#
# ```
# あなたの身長は149cm以下です
# ```
# * 150または151を入力したとき
#
# ```
# あなたの身長は150cm以上151cm以下です
# ```
# * 上記の条件を満たさなかったとき
#
# ```
# あなたの身長は152cm以上です
# ```
#
# 【注意】小数でも動作はしますが、数値以外を入力するとエラーになります。
# (小数の場合、出力される文章との整合性は取れなくなります)

# %%
# ここにリスト6.21のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト6.22のコードを書き写してみましょう。
#
# 実行後、以下の文字列が表示されれば成功です。
#
# * 149以下の整数を入力したとき
#
# ```
# あなたの身長は149cm以下です
# あなたの身長は151cm以下です
# ```
# * 150または151を入力したとき
#
# ```
# あなたの身長は151cm以下です
# ```
# * 上記の条件を満たさなかったとき
#
# ```
# あなたの身長は152cm以上です
# ```
#
# 【注意】小数でも動作はしますが、数値以外を入力するとエラーになります。
# (小数の場合、出力される文章との整合性は取れなくなります)

# %%
# ここにリスト6.22のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# 以下のコード(リスト6.23)を実行し、リスト6.21と出力結果が同じことを確認しましょう。

# %%
height = int(input("あなたの身長は何cm？"))
if height <= 149:
    print("あなたの身長は149cm以下です")
if 149 < height <= 151:
    print("あなたの身長は150cm以上151cm以下です")
else:
    print("あなたの身長は152cm以上です")

# %% [markdown]
# ---

# %% [markdown]
# 以下のコード(リスト6.24)を実行し、いずれかの整数を入力してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# (※ここに何かしらの文字が入ります).py in <cell line: 0>()
#       1 age = input("あなたの年齢は？")
# ----> 2 if age >= 18:
#       3     print("あなたは成人です")
#       4 else:
#       5     print("あなたは未成年者です")
#
# TypeError: '>=' not supported between instances of 'str' and 'int'
# ```

# %%
age = input("あなたの年齢は？")
if age >= 18:
    print("あなたは成人です")
else:
    print("あなたは未成年者です")

# %% [markdown]
# ---

# %% [markdown]
# 以下のコード(リスト6.25)を実行し、「2」や「3」と入力しても「あなたは成人です」と表示されることを確認しましょう。

# %%
age = input("あなたの年齢は？")
if age >= "18":
    print("あなたは成人です")
else:
    print("あなたは未成年者です")

# %% [markdown]
# ## 6.3　for文

# %% [markdown]
# ### 6.3.1　for文の基本

# %% [markdown]
# リスト6.27のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 大石泉
# 久川颯
# 夢見りあむ
# ```

# %%
# ここにリスト6.27のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト6.28のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 大
# 石
# 泉
# ```

# %%
# ここにリスト6.28のコードを書き写す

# %% [markdown]
# ### 6.3.2　入れ子になっているfor文

# %% [markdown]
# リスト6.29のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 大
# 石
# 泉
# 久
# 川
# 颯
# 夢
# 見
# り
# あ
# む
# ```

# %%
# ここにリスト6.29のコードを書き写す

# %% [markdown]
# ### 6.3.3　range()

# %% [markdown]
# リスト6.30のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 0
# 1
# 2
# ```

# %%
# ここにリスト6.30のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト6.31のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# Hello, world!
# Hello, world!
# Hello, world!
# ```

# %%
# ここにリスト6.31のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト6.32のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 大石泉
# 久川颯
# 夢見りあむ
# ```

# %%
# ここにリスト6.32のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト6.33のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# Hello, world!
# Hello, world!
# Hello, world!
# ```

# %%
# ここにリスト6.33のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# 【おまけ】以下のコードを実行し、変数 `_` の中に値が残っていることを確認しましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 2
# ```
# 【注意】リスト6.33の後に実行してください。

# %%
print(_)

# %% [markdown]
# ### 6.3.4　f文字列

# %% [markdown]
# リスト6.34のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 私は大石泉。15歳のアイドルだよ
# ```

# %%
# ここにリスト6.34のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト6.35のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# (中略)
# 9 x 9 = 81
# ```

# %%
# ここにリスト6.35のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# 以下のコード(リスト6.36)を実行し、リスト6.34と出力結果が同じことを確認しましょう。

# %%
for i in range(9):
    for j in range(9):
        print(f"{i + 1} x {j + 1} = {(i + 1) * (j + 1)}")

# %% [markdown]
# ### 6.3.5　enumerate()

# %% [markdown]
# リスト6.37のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 1人目は大石泉です。
# 2人目は久川颯です。
# 3人目は夢見りあむです。
# ```
#
# 続いて、リスト6.38のように、`enumerate()` に引数 `start=1` を追加し、f文字列の中を `i` 人目に変更しましょう。再度実行し、出力結果が同じことを確認しましょう。

# %%
# ここにリスト6.37および6.38のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# 以下のコード(リスト6.39および6.40)を実行し、リスト6.37と出力結果が同じことを確認しましょう。

# %%
# リスト6.39
name_list = ["大石泉", "久川颯", "夢見りあむ"]
i = 1
for name in name_list:
    print(f"{i}人目は{name}です。")
    i += 1

# %%
# リスト6.40
name_list = ["大石泉", "久川颯", "夢見りあむ"]
for i in range(len(name_list)):
    print(f"{i+1}人目は{name_list[i]}です。")

# %% [markdown]
# ## 6.4　if文とfor文の組み合わせ

# %% [markdown]
# ### 6.4.1　ケース1: 3の倍数かを判定する

# %% [markdown]
# リスト6.41のコードを書き写してみましょう。
#
# 実行後、以下の文字列が表示されれば成功です。
#
# * 3の倍数を入力したとき
#
# ```
# (入力した値)は3の倍数です
# ```
# * 3の倍数以外を入力したとき
#
# ```
# (入力した値)は3の倍数ではありません
# ```
#
# 【注意】小数でも動作はしますが、数値以外を入力するとエラーになります。

# %%
# ここにリスト6.41のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト6.42のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 1は3の倍数ではありません
# 2は3の倍数ではありません
# 3は3の倍数です
# 4は3の倍数ではありません
# 5は3の倍数ではありません
# 6は3の倍数です
# 7は3の倍数ではありません
# 8は3の倍数ではありません
# 9は3の倍数です
# 10は3の倍数ではありません
# ```

# %%
# ここにリスト6.42のコードを書き写す

# %% [markdown]
# ### 6.42　ケース2: 数値だけを抽出する

# %% [markdown]
# リスト6.43のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# (※ここに何かしらの文字が入ります).py in <cell line: 0>()
#       1 # ここにリスト6.43のコードを書き写す
#       2 weight_list = [41, 42, "リンゴたくさん", 38, 42]
# ----> 3 print(sum(weight_list) / len(weight_list))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
# ```

# %%
# ここにリスト6.43のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# リスト6.44のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# [41, 42, 38, 42]
# 40.75
# ```

# %%
# ここにリスト6.44のコードを書き写す

# %% [markdown]
# ---

# %% [markdown]
# 以下のコード(リスト6.45)を実行し、リスト6.44と出力結果が同じことを確認しましょう。
#
# 続いて、`continue` を `break` に変更し、出力結果が以下のように変わることを確認しましょう。
#
# ```
# [41, 42]
# 41.5
# ```

# %%
weight_list = [41, 42, "リンゴたくさん", 38, 42]
only_int_weight_list = []

for weight in weight_list:
    if not isinstance(weight, int):
        continue
    only_int_weight_list.append(weight)

print(only_int_weight_list)
print(sum(only_int_weight_list) / len(only_int_weight_list))

# %% [markdown]
# ## 6.5　while文

# %% [markdown]
# ### 6.5.1　while文の基本と無限ループ

# %% [markdown]
# リスト6.48のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 1
# 2
# 3
# 4
# 5
# ```
# 【注意】もし無限ループに陥ってしまった場合、コードセルを右クリックし「実行を中断」をクリックしてください。

# %%
# ここにリスト6.48のコードを書き写す

# %% [markdown]
# ### 6.5.2　while文とbreak

# %% [markdown]
# リスト6.49のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# ```
# 1
# 2
# 3
# 4
# 5
# ```
# 【注意】もし無限ループに陥ってしまった場合、コードセルを右クリックし「実行を中断」をクリックしてください。

# %%
# ここにリスト6.49のコードを書き写す
