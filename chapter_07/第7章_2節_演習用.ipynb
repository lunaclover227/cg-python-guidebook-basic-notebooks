# %% [markdown]
# # 第7章　10連ガシャを作ってみよう
#
# 第7章では、10連ガシャを実際に作成します。

# %% [markdown]
# ## 7.2　ガシャの結果をprint()で表示する

# %% [markdown]
# このノートブックでは、キャラの抽選を行い、ガシャの結果を `print()` で表示します。
#
# 途中何度も書き換えるセルが前後しますが、本書を読み進めながら順を追って書いてみましょう。
#
# (リスト7.9から順に書き進めることを推奨します)

# %% [markdown]
# ### 準備セル

# %% [markdown]
# 後続の抽選セルを実行するために、準備セルを事前に実行しておく必要があります。

# %%
import random

# %% [markdown]
# ### 変数セル

# %% [markdown]
# 【注意】変数セルを書き写す前に、後続の抽選セルにリスト7.9のコードを書き写し、一度実行しておくことを推奨します。
#
# 以下のコードセルに、リスト7.10, 7.17および7.18のコードを順に書き写してみましょう。このとき、**前に書いたコードは消してはいけません**(3つのコードを順に書き写しましょう)。
#
# このセルは実行しても何も表示されません。

# %%
# ここにリスト7.10, 7.17および7.18のコードを書き写す

# %% [markdown]
# ### 抽選セル

# %% [markdown]
# まずはじめに、以下のコードセルを補うように、リスト7.9のコードを書き写してみましょう。
#
# 想定される出力結果は次の通りです。
#
# 【注意】出力結果はランダムなため、下記は一例です。
#
# ```
# [`うさぎ`, `ぴにゃこら太`, `ぴにゃこら太`, `辻野あかり`, `ぴにゃこら太`, `久川颯`, `うさぎ`, `うさぎ`, `ぴにゃこら太`, `村松さくら`]
# ```

# %%
normal_results = random.choices(["SSレア", "Sレア", "レア"], [3, 10, 87], k=9)
last_results = random.choices(["SSレア", "Sレア"], [3, 97], k=1)
rarity_results = normal_results + last_results

######## リスト7.9を参照し、この下にキャラを抽選するコードを書く ########



######## リスト7.9を参照し、この上にキャラを抽選するコードを書く ########

print(rarity_results)

# %% [markdown]
# 続いて、リスト7.11を参照し、辞書を利用したコードに書き換えてみましょう。**変数セル実行後**に抽選セルを実行し、先程と同様に10人分のキャラ名が出力されることを確認します。
#
# その後、出力セル(リスト7.13～)作成にあたり、末尾の行の `print()` を削除します。これ以降、抽選セルを実行しても何も表示されなくなります。
#
# 最後に、**変数セルにリスト7.18のコードを書き写したあと**、リスト7.19を参照し1行目と2行目の抽選処理を書き換えてみましょう。

# %% [markdown]
# ### 出力セル

# %% [markdown]
# 以下のコードセルに、リスト7.13から7.16のコードを順に書き写してみましょう。
#
# 想定される出力結果はそれぞれ次の通りです。
#
# 【注意】出力結果はランダムなため、下記は一例です。
#
# * リスト7.13
# ```
# 1人目: うさぎ
# 2人目: ぴにゃこら太
# 3人目: ぴにゃこら太
# 4人目: 辻野あかり
# 5人目: ぴにゃこら太
# 6人目: 久川颯
# 7人目: うさぎ
# 8人目: うさぎ
# 9人目: ぴにゃこら太
# 10人目: 村松さくら
# ```
#
# * リスト7.14
# ```
# [レア] うさぎ
# [レア] ぴにゃこら太
# [レア] ぴにゃこら太
# [Sレア] 辻野あかり
# [レア] ぴにゃこら太
# [SSレア] 久川颯
# [レア] うさぎ
# [レア] うさぎ
# [レア] ぴにゃこら太
# [Sレア] 村松さくら
# ```
#
# * リスト7.15および7.16
# ```
# 1人目: [レア] うさぎ
# 2人目: [レア] ぴにゃこら太
# 3人目: [レア] ぴにゃこら太
# 4人目: [Sレア] 辻野あかり
# 5人目: [レア] ぴにゃこら太
# 6人目: [SSレア] 久川颯
# 7人目: [レア] うさぎ
# 8人目: [レア] うさぎ
# 9人目: [レア] ぴにゃこら太
# 10人目: [Sレア] 村松さくら
# ```

# %%
# ここにリスト7.13から7.16のコードを書き写す
