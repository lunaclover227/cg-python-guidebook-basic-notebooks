# %% [markdown]
# # 第7章　10連ガシャを作ってみよう
#
# 第7章では、10連ガシャを実際に作成します。

# %% [markdown]
# ## 7.1　レア度の決定

# %% [markdown]
# このノートブックでは、レア度の決定を行います。

# %% [markdown]
# ### 準備セル

# %% [markdown]
# 以下のコードセルに、リスト7.2のコードを書き写してみましょう。
#
# 後続の抽選セルを実行するために、準備セルを事前に実行しておく必要があります。

# %%
# ここにリスト7.2のコードを書き写す

# %% [markdown]
# ### 抽選セル

# %% [markdown]
# 以下のコードセルに、リスト7.3から7.6のコードを順に書き写してみましょう。
#
# 想定される出力結果はそれぞれ次の通りです。
#
# 【注意】出力結果はランダムなため、下記は一例です。
#
# * リスト7.3 (何も表示されない)
#
# * リスト7.4および7.5
# ```
# ['レア', 'レア', 'レア', 'Sレア', 'レア', 'レア', 'Sレア', 'SSレア', 'レア', 'レア']
# ```
#
# * リスト7.6 (何度実行しても最後の1回がSレア以上であることを確認する)
# ```
# ['レア', 'レア', 'Sレア', 'レア', 'レア', 'SSレア', 'レア', 'レア', 'レア', 'Sレア']
# ```

# %%
# ここにリスト7.3から7.6のコードを書き写す
